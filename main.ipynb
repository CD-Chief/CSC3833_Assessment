# %%
import pandas as pd
df = pd.read_excel('CountryEconomics.xlsx')

# %% [markdown]
# ## Data columns
# Country	ID	Abbreviation	Currency	Capital	Languages	Latitude	Longitude	Area	Population	Region	Subregion	Borders	GDP	GDP Growth	Interest Rate	Inflation Rate	Jobless Rate	Gov. Budget	Debt/GDP	Current Account

# %%
import altair as alt
from vega_datasets import data
chart = alt.Chart(df).mark_bar().encode(
    x='Country',
    y='GDP'
)
chart.show()
# Out:
# alt.Chart(...)

# %%
world_map = alt.topo_feature(data.world_110m.url, 'countries')

chart = alt.Chart(world_map).mark_geoshape().encode(
    color='GDP:Q',
    tooltip=['Country:N', 'GDP:Q']
).transform_lookup(
    lookup='id',
    from_=alt.LookupData(df, 'ID', ['Country', 'GDP'])
).project('mercator').properties(
    width=800,
    height=400
)
chart
# Out:
# alt.Chart(...)
